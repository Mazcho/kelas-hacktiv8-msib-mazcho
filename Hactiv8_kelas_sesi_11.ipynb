# %% [markdown]
# # Machine Learning - Regresi

# %% [markdown]
# ![image.png](attachment:18c206dd-7c17-4e4a-a70f-7716802b2b0b.png)

# %% [markdown]
# ![image.png](attachment:1765b0ca-ae64-409e-abab-5bd3cb965eb6.png)

# %% [markdown]
# ## Regresi
# Model yang menghasilkan angka daripada kelas/kategori

# %% [markdown]
# ![image.png](attachment:2bcdf412-d0c9-4ef6-a8fc-34b4558411c7.png)

# %% [markdown]
# y = 2x + 3

# %%
x = int(input())
y = 2*x +3
print(y)
# Out:
#  10
# 23

# %% [markdown]
# ![image.png](attachment:d8b24503-f9d0-4eab-a935-972dc965658a.png)

# %% [markdown]
# ![image.png](attachment:1d46fc0a-94c0-45ee-9ecb-e0ef5ca3108d.png)

# %% [markdown]
# ## Underfitting Overfitting

# %% [markdown]
# ![image.png](attachment:edf83f3b-d30f-48ad-b723-7968ad8f371b.png)

# %% [markdown]
# 1. Metric pada Data Training Jauh Lebih Baik dibandingkan pada testing (Overfitting)
# 2. Metric pada Data Training Jauh Lebih Buruk dibandingkan pada testing (Underfitting)
# 3. Metric pada Data Training Sama baiknya dibandingkan data testing (Well-Fit)

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# %matplotlib inline

# %% [markdown]
# ## Simple Linear Regression

# %%
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1,1)) 
y = np.array([5, 20, 14, 32, 22, 38])

# %%
print(x)
print(y)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [ 5 20 14 32 22 38]

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
# R-Squared
r_sq = model.score(x,y)
r_sq
# Out:
# 0.7158756137479542

# %%
print('intercept :', model.intercept_)
print('slope:',model.coef_)
# Out:
# intercept : 5.633333333333329
# slope: [0.54]

# %% [markdown]
# y = mx + b
#
# y adalah target
#
# m adalah slope
#
# b adalah intercept

# %%
print('Formula dari Model adalah y = ',model.coef_[0], 'x +',model.intercept_)
# Out:
# Formula dari Model adalah y =  0.54 x + 5.633333333333329

# %%
y_pred = model.predict(x)
y_pred
# Out:
# array([ 8.33333333, 13.73333333, 19.13333333, 24.53333333, 29.93333333,
#        35.33333333])

# %%
print(x)
print(y)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [ 5 20 14 32 22 38]

# %%
plt.scatter(x,y,alpha=0.5)
plt.plot(x,y_pred)

plt.title('Scatter Plot x and y')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x_new = np.arange(5,20,5).reshape([-1,1])
print(x_new)
# Out:
# [[ 5]
#  [10]
#  [15]]

# %%
y_new_pred = model.predict(x_new)
print(y_new_pred)
# Out:
# [ 8.33333333 11.03333333 13.73333333]

# %% [markdown]
# ## Multiple Linear Regression

# %%
x = np.array([[0,1],
             [5,1],
             [15,2],
             [25,5],
             [35,11],
             [45,15],
             [55,34],
             [60,35]])
y = np.array([4, 5, 20, 14, 32, 22, 38, 43])

print(x,'\n',y)
# Out:
# [[ 0  1]
#  [ 5  1]
#  [15  2]
#  [25  5]
#  [35 11]
#  [45 15]
#  [55 34]
#  [60 35]]
#  [ 4  5 20 14 32 22 38 43]

# %%
model = LinearRegression()

# %%
x.shape
# Out:
# (8, 2)

# %%
y.shape
# Out:
# (8,)

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
r_sq_multi = model.score(x,y)
r_sq_multi
# Out:
# 0.8615939258756776

# %%
model.intercept_
# Out:
# 5.522579275198183

# %%
model.coef_
# Out:
# array([0.44706965, 0.25502548])

# %%
print('Formula Mutiple LinReg adalah y =',model.coef_[0],'x1 +',model.coef_[1],'x2 +',model.intercept_)
# Out:
# Formula Mutiple LinReg adalah y = 0.4470696489241224 x1 + 0.2550254813137035 x2 + 5.522579275198183

# %%
y_pred_multi = model.predict(x)

# %%
y_pred_multi
# Out:
# array([ 5.77760476,  8.012953  , 12.73867497, 17.9744479 , 23.97529728,
#        29.4660957 , 38.78227633, 41.27265006])

# %%
y
# Out:
# array([ 4,  5, 20, 14, 32, 22, 38, 43])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mse_multi = mean_squared_error(y,y_pred_multi)
mse_multi
# Out:
# 25.56187181483579

# %%
rmse = (mse_multi)**0.5
rmse
# Out:
# 5.055874980142981

# %% [markdown]
# ## Polynomial Regression

# %% [markdown]
# ![image.png](attachment:7818208e-e80d-422c-b670-e43ada90926e.png)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
x = np.array([5, 15 , 25, 35, 45, 55]).reshape([-1,1])
y = np.array([15, 11, 2, 8, 25, 32])

print(x)
print(y)
# Out:
# [[ 5]
#  [15]
#  [25]
#  [35]
#  [45]
#  [55]]
# [15 11  2  8 25 32]

# %%
plt.scatter(x,y)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
y_pred = model.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)

# %%
model.score(x,y)
# Out:
# 0.4065969428801287

# %%
transformer = PolynomialFeatures(include_bias=False)

# %%
transformer.fit(x)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
x_poly = transformer.transform(x)
x_poly
# Out:
# array([[   5.,   25.],
#        [  15.,  225.],
#        [  25.,  625.],
#        [  35., 1225.],
#        [  45., 2025.],
#        [  55., 3025.]])

# %%
x_poly = transformer.fit_transform(x)
x_poly
# Out:
# array([[   5.,   25.],
#        [  15.,  225.],
#        [  25.,  625.],
#        [  35., 1225.],
#        [  45., 2025.],
#        [  55., 3025.]])

# %%
x_poly
# Out:
# array([[   5.,   25.],
#        [  15.,  225.],
#        [  25.,  625.],
#        [  35., 1225.],
#        [  45., 2025.],
#        [  55., 3025.]])

# %%
model_poly = LinearRegression()
model_poly.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
model_poly.score(x_poly,y)
# Out:
# 0.8908516262498563

# %%
model.score(x,y)
# Out:
# 0.4065969428801287

# %%
y_poly_pred = model_poly.predict(x_poly)

# %%
y
# Out:
# array([15, 11,  2,  8, 25, 32])

# %%
y_poly_pred
# Out:
# array([15.46428571,  7.90714286,  6.02857143,  9.82857143, 19.30714286,
#        34.46428571])

# %%
plt.scatter(x,y,color='red',label='true y')
plt.plot(x,y_poly_pred,color='blue',label='predicted y')
plt.legend()
plt.show()

# %% [markdown]
# # Break sampai 3.30 pm WIB

# %% [markdown]
# ## Multiple Polynomial Regression

# %%
x = np.array([[0,1],
             [5,1],
             [15,2],
             [25,5],
             [35,11],
             [45,15],
             [55,34],
             [60,35]])
y = np.array([4, 5, 20, 14, 32, 22, 38, 43])

# %%
x_poly = transformer.fit_transform(x)
model_poly = LinearRegression()
model = LinearRegression()
model_poly.fit(x_poly,y)
model.fit(x,y)
# Out:
# LinearRegression()

# %%
print(model.score(x,y),model_poly.score(x_poly,y))
# Out:
# 0.8615939258756776 0.9453701449127824

# %%
x_0 = [i[0] for i in x]

# %%
x_1 = [i[1] for i in x]

# %%
plt.scatter(x_0,y)

# %%
plt.scatter(x_1,y)

# %%
y_pred = model.predict(x)
y_pred_poly = model_poly.predict(x_poly)
mse  = mean_squared_error(y,y_pred)
mse_poly = mean_squared_error(y,y_pred_poly)
rmse = np.sqrt(mse)
rmse_poly = np.sqrt(mse_poly)
print(rmse,rmse_poly)
# Out:
# 5.055874980142981 3.176389674051423

# %% [markdown]
# ## Advanced Linear Regression with Statsmodels

# %%
import statsmodels.api as sm

# %%
x = np.array([[0,1],
             [5,1],
             [15,2],
             [25,5],
             [35,11],
             [45,15],
             [55,34],
             [60,35]])
y = np.array([4, 5, 20, 14, 32, 22, 38, 43])

# %%
x = sm.add_constant(x)

# %%
x
# Out:
# array([[ 1.,  0.,  1.],
#        [ 1.,  5.,  1.],
#        [ 1., 15.,  2.],
#        [ 1., 25.,  5.],
#        [ 1., 35., 11.],
#        [ 1., 45., 15.],
#        [ 1., 55., 34.],
#        [ 1., 60., 35.]])

# %%
model_stat = sm.OLS(y,x)

# %%
results = model_stat.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.862
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     15.56
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):            0.00713
# Time:                        15:56:41   Log-Likelihood:                -24.316
# No. Observations:                   8   AIC:                             54.63
# Df Residuals:                       5   BIC:                             54.87
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.5226      4.431      1.246      0.268      -5.867      16.912
# x1             0.4471      0.285      1.567      0.178      -0.286       1.180
# x2             0.2550      0.453      0.563      0.598      -0.910       1.420
# ==============================================================================
# Omnibus:                        0.561   Durbin-Watson:                   3.268
# Prob(Omnibus):                  0.755   Jarque-Bera (JB):                0.534
# Skew:                           0.380   Prob(JB):                        0.766
# Kurtosis:                       1.987   Cond. No.                         80.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\fachr\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=8
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %% [markdown]
# formula regresi: y = 5.5226 + 0.4471x1 + 0.2550x2

# %%
print('rsquared:',results.rsquared)
# Out:
# rsquared: 0.8615939258756776

# %%
results.params
# Out:
# array([5.52257928, 0.44706965, 0.25502548])

# %%
res_summary = results.summary()
res_summary.tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
res_summary.tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
y_pred = results.predict(x)

# %%
mse = mean_squared_error(y,y_pred)

# %%
np.sqrt(mse)
# Out:
# 5.05587498014298

# %% [markdown]
# ## Implementing Linear Regression on Real Dataset

# %%
import statsmodels.api as sm
from sklearn import datasets
import pandas as pd

# %% [markdown]
#  Variables in order:
#  CRIM     per capita crime rate by town
#  ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#  INDUS    proportion of non-retail business acres per town
#  CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  NOX      nitric oxides concentration (parts per 10 million)
#  RM       average number of rooms per dwelling
#  AGE      proportion of owner-occupied units built prior to 1940
#  DIS      weighted distances to five Boston employment centres
#  RAD      index of accessibility to radial highways
#  TAX      full-value property-tax rate per $10,000
#  PTRATIO  pupil-teacher ratio by town
#  B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  LSTAT    % lower status of the population
#  MEDV     Median value of owner-occupied homes in $1000's

# %%
df = pd.read_csv('BostonHousing.csv')

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
x = df.drop('medv',axis=1)
y = df['medv']

# %%
x=x[['rm']]
model = sm.OLS(y,x)
results = model.fit()
predictions = results.predict(x)
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   medv   R-squared (uncentered):                   0.901
# Model:                            OLS   Adj. R-squared (uncentered):              0.901
# Method:                 Least Squares   F-statistic:                              4615.
# Date:                Thu, 30 Mar 2023   Prob (F-statistic):                   3.74e-256
# Time:                        16:15:11   Log-Likelihood:                         -1747.1
# No. Observations:                 506   AIC:                                      3496.
# Df Residuals:                     505   BIC:                                      3500.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# rm             3.6534      0.054     67.930      0.000       3.548       3.759
# ==============================================================================
# Omnibus:                       83.295   Durbin-Watson:                   0.493
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              152.507
# Skew:                           0.955   Prob(JB):                     7.65e-34
# Kurtosis:                       4.894   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
plt.scatter(x,y)
plt.plot(x,predictions)

# %% [markdown]
# ## Use SKLEARN for boston

# %%
X = df.drop('medv',1)
y = df['medv']
# Out:
# C:\Users\fachr\AppData\Local\Temp\ipykernel_35936\3720231293.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = df.drop('medv',1)

# %%
linreg = LinearRegression()

# %%
linreg.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(X)

# %%
linreg.score(X,y)
# Out:
# 0.7406426641094094

# %% [markdown]
# ## Contoh kedua sklearn

# %%
df = pd.read_csv('CarPrice_Assignment.csv',usecols=['horsepower','price'])

# %%
df
# Out:
#      horsepower    price
# 0           111  13495.0
# 1           111  16500.0
# 2           154  16500.0
# 3           102  13950.0
# 4           115  17450.0
# ..          ...      ...
# 200         114  16845.0
# 201         160  19045.0
# 202         134  21485.0
# 203         106  22470.0
# 204         114  22625.0
#
# [205 rows x 2 columns]

# %%
f = plt.figure(figsize=(12,4))

f.add_subplot(1,2,1)
df['horsepower'].plot(kind='kde')

f.add_subplot(1,2,2)
df['horsepower'].plot(kind='box')

plt.show()

# %%
X = df['horsepower']
y = df['price']
plt.scatter(X,y)
plt.ylabel('price')
plt.xlabel('horsepower')
# Out:
# Text(0.5, 0, 'horsepower')

# %%
df.corr()
# Out:
#             horsepower     price
# horsepower    1.000000  0.808139
# price         0.808139  1.000000

# %%
X = X.to_frame()

# %% [markdown]
# # Data Splitting

# %% [markdown]
# ![image.png](attachment:90399935-2d9d-420d-b2bb-5e89a1ae575d.png)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
linreg = LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
linreg.score(X_train,y_train)
# Out:
# 0.6492990837589783

# %%
y_pred = linreg.predict(X_test)

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,y_pred)

# %%
y_pred_train = linreg.predict(X_train)
y_pred_test = linreg.predict(X_test)

# %%
mse_train = mean_squared_error(y_train,y_pred_train)
mse_test = mean_squared_error(y_test,y_pred_test)
rmse_tr = np.sqrt(mse_train)
rmse_test = np.sqrt(mse_test)
print('train mse:',mse_train)
print('test mse',mse_test)
print('train rmse',rmse_tr)
print('test rmse',rmse_test)
# Out:
# train mse: 22162777.50057767
# test mse 21597979.932229538
# train rmse 4707.735920862349
# test rmse 4647.36268567771
