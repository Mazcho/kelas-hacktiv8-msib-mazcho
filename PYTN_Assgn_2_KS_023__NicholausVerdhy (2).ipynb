# %% [markdown]
# Nama Mahasiswa    : Nicholaus Verdhy Putranto
#
# Asal Universitas  : Universitas Dian Nuswwantoro Semarang
#
# Kode Peserta      : PYTN - KS11 - 023

# %% [markdown]
# # Import Libray Yang dibutuhkan

# %% [markdown]
# >1. NumPy adalah library Python yang digunakan untuk melakukan komputasi numerik dalam bahasa Python.
#
# >2. Pandas adalah library Python yang digunakan untuk melakukan analisis data.
#
# >3. Seaborn adalah library Python yang digunakan untuk melakukan visualisasi data.
#
# >4. Statsmodels adalah library Python yang digunakan untuk melakukan analisis statistik.
#
# >5. Matplotlib adalah library Python yang digunakan untuk membuat visualisasi data secara umum.
#
# >6. Math adalah library Python yang digunakan untuk melakukan operasi matematika dasar.
#
# >7. Statistics adalah library Python yang digunakan untuk melakukan operasi statistik dasar.
#
# >8. Scipy.stats adalah library Python yang digunakan untuk melakukan analisis statistik lanjutan.
#
# >7. Warnings adalah library Python yang digunakan untuk menghasilkan peringatan saat ada situasi yang tidak diharapkan terjadi pada kode program.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import statistics
import scipy.stats
import random

# %% [markdown]
# # Memanggil data

# %% [markdown]
# Sekarang mari kita panggil datanya menggunakan fungsi pada pandas dengan read_csv

# %%
df = pd.read_csv("nyc-rolling-sales.csv")
df
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %% [markdown]
# # Pengenalan Data

# %% [markdown]
# Setelah kita panggil datanya, mari kita kenali datanya, mulai dari tipe datanya,, jumlah datanya dan lainnya

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84548 entries, 0 to 84547
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      84548 non-null  int64
#  1   BOROUGH                         84548 non-null  int64
#  2   NEIGHBORHOOD                    84548 non-null  object
#  3   BUILDING CLASS CATEGORY         84548 non-null  object
#  4   TAX CLASS AT PRESENT            84548 non-null  object
#  5   BLOCK                           84548 non-null  int64
#  6   LOT                             84548 non-null  int64
#  7   EASE-MENT                       84548 non-null  object
#  8   BUILDING CLASS AT PRESENT       84548 non-null  object
#  9   ADDRESS                         84548 non-null  object
#  10  APARTMENT NUMBER                84548 non-null  object
#  11  ZIP CODE                        84548 non-null  int64
# ...

# %%
df.shape
# Out:
# (84548, 22)

# %%
df.isna().sum()
# Out:
# Unnamed: 0                        0
# BOROUGH                           0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# EASE-MENT                         0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          Unnamed: 0       BOROUGH         BLOCK           LOT      ZIP CODE  \
# count  84548.000000  84548.000000  84548.000000  84548.000000  84548.000000
# mean   10344.359878      2.998758   4237.218976    376.224015  10731.991614
# std     7151.779436      1.289790   3568.263407    658.136814   1290.879147
# min        4.000000      1.000000      1.000000      1.000000      0.000000
# 25%     4231.000000      2.000000   1322.750000     22.000000  10305.000000
# 50%     8942.000000      3.000000   3311.000000     50.000000  11209.000000
# 75%    15987.250000      4.000000   6281.000000   1001.000000  11357.000000
# max    26739.000000      5.000000  16322.000000   9106.000000  11694.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS    YEAR BUILT  \
# count       84548.000000      84548.000000  84548.000000  84548.000000
# mean            2.025264          0.193559      2.249184   1789.322976
# ...

# %% [markdown]
# _Keterangan_
#
# Dari data diatas kita bisa melihat tipe datanya. Akan tetapi ada beberapa tipe data yang tidak sesuai dengan varieblnya. Lalu jumlah datanya sebesar 84548 rows × 22 columns. Tidak ditemukan data yang missing value dan duplicated

# %% [markdown]
# # Data Cleansing dan Preparation Data

# %%
df
# Out:
#        Unnamed: 0  BOROUGH   NEIGHBORHOOD  \
# 0               4        1  ALPHABET CITY
# 1               5        1  ALPHABET CITY
# 2               6        1  ALPHABET CITY
# 3               7        1  ALPHABET CITY
# 4               8        1  ALPHABET CITY
# ...           ...      ...            ...
# 84543        8409        5        WOODROW
# 84544        8410        5        WOODROW
# 84545        8411        5        WOODROW
# 84546        8412        5        WOODROW
# 84547        8413        5        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...

# %% [markdown]
# Pertama kita akan mengubah nama borough menjadi nama area

# %%
df.rename(columns={"BOROUGH":"AREA"},inplace=True)

# %% [markdown]
# Setelah mengubah nama kolom borough menjadi area, sekarang kita mengubah isi data pada kolom borough dengan beberapa kategori

# %% [markdown]
# AREA berisi kode properti
# 1. Manhattan
# 2. Bronx
# 3. Brooklyn
# 4. Queens
# 5. Staten Island

# %%
df['AREA'] = df.AREA.replace({1: "Manhattan", 2: "Bronx", 3: "Brooklyn", 4: "Queens", 5: "Staten Islands"})

# %%
df
# Out:
#        Unnamed: 0            AREA   NEIGHBORHOOD  \
# 0               4       Manhattan  ALPHABET CITY
# 1               5       Manhattan  ALPHABET CITY
# 2               6       Manhattan  ALPHABET CITY
# 3               7       Manhattan  ALPHABET CITY
# 4               8       Manhattan  ALPHABET CITY
# ...           ...             ...            ...
# 84543        8409  Staten Islands        WOODROW
# 84544        8410  Staten Islands        WOODROW
# 84545        8411  Staten Islands        WOODROW
# 84546        8412  Staten Islands        WOODROW
# 84547        8413  Staten Islands        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# ...

# %% [markdown]
# Setelah mengubah dengan sesuai nama areanya, sekarang kita mengahpus kolom yang tidak dibutuhkan menggunakan drop kolom. Kolom yang tidak dipakai dalah Unnamed: 0 dan EASE_MEANT

# %%
df.drop(["Unnamed: 0","EASE-MENT"],axis=1,inplace=True)
df
# Out:
#                  AREA   NEIGHBORHOOD  \
# 0           Manhattan  ALPHABET CITY
# 1           Manhattan  ALPHABET CITY
# 2           Manhattan  ALPHABET CITY
# 3           Manhattan  ALPHABET CITY
# 4           Manhattan  ALPHABET CITY
# ...               ...            ...
# 84543  Staten Islands        WOODROW
# 84544  Staten Islands        WOODROW
# 84545  Staten Islands        WOODROW
# 84546  Staten Islands        WOODROW
# 84547  Staten Islands        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...                                            ...                  ...
# ...

# %% [markdown]
# Mari Kita cek data yang duplikat

# %%
df.duplicated().sum()
# Out:
# 765

# %% [markdown]
# DAta yang duplicated ada 765. Data tersebut tidak lebih dari 10%. Mari kita delete saja data nya agar tidak terjadi kesalahan pada analisis

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Sekarang mari kita ubah tipe data yang tidak sesuai dengan variabelnya

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   AREA                            83783 non-null  object
#  1   NEIGHBORHOOD                    83783 non-null  object
#  2   BUILDING CLASS CATEGORY         83783 non-null  object
#  3   TAX CLASS AT PRESENT            83783 non-null  object
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83783 non-null  object
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                83783 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
# ...

# %% [markdown]
# Sekarang mari kita ubah untuk kolom 13,14,18 keadalam int

# %% [markdown]
# Kita gunakan perulangan untuk mengecek kolom untuk megubhanya menjadi dalam bentuk numrik, Nanti ada errors="coerce"  yang gunanya untuk membuat nilai yang tidak bisa dikonver jadi NAn

# %%
numerical_ = ["LAND SQUARE FEET","GROSS SQUARE FEET","SALE PRICE"]

for column in numerical_:
    df[column]=pd.to_numeric(df[column],errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   AREA                            83783 non-null  object
#  1   NEIGHBORHOOD                    83783 non-null  object
#  2   BUILDING CLASS CATEGORY         83783 non-null  object
#  3   TAX CLASS AT PRESENT            83783 non-null  object
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83783 non-null  object
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                83783 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
# ...

# %% [markdown]
# Sekarang kita ubah 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'BUILDING CLASS AT TIME OF SALE', 'TAX CLASS AT TIME OF SALE', 'AREA' menjadi category

# %%
category_ = ['NEIGHBORHOOD', 'BUILDING CLASS CATEGORY', 'TAX CLASS AT PRESENT', 'BUILDING CLASS AT TIME OF SALE', 'TAX CLASS AT TIME OF SALE', 'AREA']
for column in category_:
    df[column]=df[column].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   AREA                            83783 non-null  category
#  1   NEIGHBORHOOD                    83783 non-null  category
#  2   BUILDING CLASS CATEGORY         83783 non-null  category
#  3   TAX CLASS AT PRESENT            83783 non-null  category
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83783 non-null  object
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                83783 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
# ...

# %% [markdown]
# Guna dari category adalah digunakan untuk menyimpan data kategorikal atau data yang terdiri dari sejumlah kategori. Ini digunakan untuk mengurangi penggunaan memori, meningkatkan kecepatan pemrosesan data.

# %% [markdown]
# ================================================
#
# Mari kita ubah sale date menjadi timestamp

# %%
df["SALE DATE"] = pd.to_datetime(df["SALE DATE"], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83783 entries, 0 to 84547
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   AREA                            83783 non-null  category
#  1   NEIGHBORHOOD                    83783 non-null  category
#  2   BUILDING CLASS CATEGORY         83783 non-null  category
#  3   TAX CLASS AT PRESENT            83783 non-null  category
#  4   BLOCK                           83783 non-null  int64
#  5   LOT                             83783 non-null  int64
#  6   BUILDING CLASS AT PRESENT       83783 non-null  object
#  7   ADDRESS                         83783 non-null  object
#  8   APARTMENT NUMBER                83783 non-null  object
#  9   ZIP CODE                        83783 non-null  int64
#  10  RESIDENTIAL UNITS               83783 non-null  int64
#  11  COMMERCIAL UNITS                83783 non-null  int64
# ...

# %% [markdown]
# Stelah semua tipe data yang saya inginkan sudah sesuai, mari kita cek lagi apakah ada missing value dari konvert tipe data tsb

# %%
df.isna().sum()
# Out:
# AREA                                  0
# NEIGHBORHOOD                          0
# BUILDING CLASS CATEGORY               0
# TAX CLASS AT PRESENT                  0
# BLOCK                                 0
# LOT                                   0
# BUILDING CLASS AT PRESENT             0
# ADDRESS                               0
# APARTMENT NUMBER                      0
# ZIP CODE                              0
# RESIDENTIAL UNITS                     0
# COMMERCIAL UNITS                      0
# TOTAL UNITS                           0
# LAND SQUARE FEET                  26054
# GROSS SQUARE FEET                 27385
# YEAR BUILT                            0
# TAX CLASS AT TIME OF SALE             0
# BUILDING CLASS AT TIME OF SALE        0
# SALE PRICE                        14176
# SALE DATE                             0
# dtype: int64

# %% [markdown]
# Ternyata terdapat missing value pada Land Square, Gross Square, Sale Price
#
# mari kita gantikan missing value tsbt dengan nilai mean

# %%
df.describe()
# Out:
#               BLOCK           LOT      ZIP CODE  RESIDENTIAL UNITS  \
# count  83783.000000  83783.000000  83783.000000       83783.000000
# mean    4242.903155    376.137415  10733.236575           1.999976
# std     3568.789482    658.021286   1289.764300          16.569118
# min        1.000000      1.000000      0.000000           0.000000
# 25%     1326.000000     22.000000  10305.000000           0.000000
# 50%     3319.000000     50.000000  11209.000000           1.000000
# 75%     6295.000000   1001.000000  11357.000000           2.000000
# max    16322.000000   9106.000000  11694.000000        1844.000000
#
#        COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  GROSS SQUARE FEET  \
# count      83783.000000  83783.000000      5.772900e+04       5.639800e+04
# mean           0.183677      2.213504      3.854481e+03       3.894416e+03
# std            8.576582     18.777727      4.154737e+04       3.483726e+04
# ...

# %%
df['LAND SQUARE FEET'].fillna(df['LAND SQUARE FEET'].mean(), inplace=True)
df['GROSS SQUARE FEET'].fillna(df['GROSS SQUARE FEET'].mean(), inplace=True)
df['SALE PRICE'].fillna(df['SALE PRICE'].mean(), inplace=True)

# %%
df
# Out:
#                  AREA   NEIGHBORHOOD  \
# 0           Manhattan  ALPHABET CITY
# 1           Manhattan  ALPHABET CITY
# 2           Manhattan  ALPHABET CITY
# 3           Manhattan  ALPHABET CITY
# 4           Manhattan  ALPHABET CITY
# ...               ...            ...
# 84543  Staten Islands        WOODROW
# 84544  Staten Islands        WOODROW
# 84545  Staten Islands        WOODROW
# 84546  Staten Islands        WOODROW
# 84547  Staten Islands        WOODROW
#
#                            BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0      07 RENTALS - WALKUP APARTMENTS                                2A
# 1      07 RENTALS - WALKUP APARTMENTS                                 2
# 2      07 RENTALS - WALKUP APARTMENTS                                 2
# 3      07 RENTALS - WALKUP APARTMENTS                                2B
# 4      07 RENTALS - WALKUP APARTMENTS                                2A
# ...                                            ...                  ...
# ...

# %%
df.isna().sum()
# Out:
# AREA                              0
# NEIGHBORHOOD                      0
# BUILDING CLASS CATEGORY           0
# TAX CLASS AT PRESENT              0
# BLOCK                             0
# LOT                               0
# BUILDING CLASS AT PRESENT         0
# ADDRESS                           0
# APARTMENT NUMBER                  0
# ZIP CODE                          0
# RESIDENTIAL UNITS                 0
# COMMERCIAL UNITS                  0
# TOTAL UNITS                       0
# LAND SQUARE FEET                  0
# GROSS SQUARE FEET                 0
# YEAR BUILT                        0
# TAX CLASS AT TIME OF SALE         0
# BUILDING CLASS AT TIME OF SALE    0
# SALE PRICE                        0
# SALE DATE                         0
# dtype: int64

# %% [markdown]
# # Measure of Conten

# %% [markdown]
# Disini kita akan mencari Nilai Mean ( rata rata ), Nilai Median ( nilai tengah), dan Nilai Modus ( nilai sering muncul) pada 5 tahun terahkir

# %% [markdown]
# ## Rumusan Masalah
# > Berapa nilai rata rata, nilai median pada penjualan unit, luas , dan harga di 5 tahun terahkir? (mean)
#
# > Berapa nilai nilai median pada penjualan unit, luas , dan harga di 5 tahun terahkir? (median)
#
# > Nilai Mayoritas manakan yang sering muncul terpacu pada daerah? (Mode)

# %% [markdown]
# ### Mean

# %% [markdown]
# Kita akan mencari Mean dari setiap tahunnya, mulai dari unit, luas, dan harga dari 5 tahun terahkir

# %%
#mean Pandas
a = df.groupby(["YEAR BUILT"])[['RESIDENTIAL UNITS','COMMERCIAL UNITS','TOTAL UNITS','LAND SQUARE FEET','GROSS SQUARE FEET','SALE PRICE']].mean()
a.tail(5)
# Out:
#             RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# YEAR BUILT
# 2013                 2.160377          0.071429     2.346361
# 2014                 2.226016          0.519512     2.886179
# 2015                 1.965870          0.561092     2.622526
# 2016                 4.092172          0.051768     4.208333
# 2017                 2.000000        141.166667   143.166667
#
#             LAND SQUARE FEET  GROSS SQUARE FEET    SALE PRICE
# YEAR BUILT
# 2013             3585.912404        4481.947674  2.882327e+06
# 2014             2533.388581        4441.436948  2.204815e+06
# 2015             2256.184251        2987.842885  1.453862e+06
# 2016             3310.539724        2495.027867  8.763765e+05
# 2017             5237.166667        1529.305271  5.719010e+05

# %% [markdown]
# #### _KETERANGAN nilai Mean_
# 1. Pada tahun 2013,
#    1. Residental Units memiliki nilai rata rata 2.160377
#    2. Commercial Units memiliki rata rata 0.071429
#    3. Total Units memiliki rata rata 2.346361
#    4. Land Square Feet  memiliki rata rata 3585.912404
#    5. Gross Square Feet memiliki rata rata 4481.947674
#    6. Sale Price dengan rata rata 2.882327e+06
#
#
# 2. Pada tahun 2014,
#    1. Residental Units memiliki nilai rata rata 2.226016
#    2. Commercial Units memiliki rata rata 0.519512
#    3. Total Units memiliki rata rata 2.886179
#    4. Land Square Feet  memiliki rata rata 2533.388581
#    5. Gross Square Feet memiliki rata rata 4441.436948
#    6. Sale Price dengan rata rata 2.204815e+06
#
#
# 3. Pada tahun 2015,
#    1. Residental Units memiliki nilai rata rata 1.965870
#    2. Commercial Units memiliki rata rata 0.561092
#    3. Total Units memiliki rata rata 2.622526
#    4. Land Square Feet  memiliki rata rata 2256.184251
#    5. Gross Square Feet memiliki rata rata 2987.842885
#    6. Sale Price dengan rata rata 1.453862e+06
#
#
# 4. Pada tahun 2016,
#    1. Residental Units memiliki nilai rata rata 4.092172
#    2. Commercial Units memiliki rata rata 0.051768
#    3. Total Units memiliki rata rata 4.208333
#    4. Land Square Feet  memiliki rata rata 3310.539724
#    5. Gross Square Feet memiliki rata rata 2495.027867
#    6. Sale Price dengan rata rata 8.763765e+05
#
#
# 5. Pada tahun 2017,
#    1. Residental Units memiliki nilai rata rata 2.000000
#    2. Commercial Units memiliki rata rata 141.166667
#    3. Total Units memiliki rata rata 143.166667
#    4. Land Square Feet  memiliki rata rata 5237.166667
#    5. Gross Square Feet memiliki rata rata 1529.305271
#    6. Sale Price dengan rata rata 5.719010e+05

# %% [markdown]
# ### Median

# %%
#median dengan pandas
b = df.groupby(["YEAR BUILT"])[['RESIDENTIAL UNITS','COMMERCIAL UNITS','TOTAL UNITS','LAND SQUARE FEET','GROSS SQUARE FEET','SALE PRICE']].median()
b.tail(5)
# Out:
#             RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# YEAR BUILT
# 2013                      1.0               0.0          1.0
# 2014                      1.0               0.0          1.0
# 2015                      1.0               0.0          1.0
# 2016                      1.0               0.0          1.0
# 2017                      0.0               1.0          6.5
#
#             LAND SQUARE FEET  GROSS SQUARE FEET    SALE PRICE
# YEAR BUILT
# 2013             3854.481179        3894.415813  9.941290e+05
# 2014             3854.481179        3894.415813  1.280703e+06
# 2015             2300.000000        2059.000000  8.858770e+05
# 2016             3000.000000        2244.000000  7.203995e+05
# 2017             3367.500000         693.500000  4.350000e+05

# %% [markdown]
# #### _KETERANGAN Nilai Median Pada tabel_
# 1. Pada tahun 2013,
#    1. Residental Units memiliki nilai median 1.0
#    2. Commercial Units memiliki median 0.0
#    3. Total Units memiliki median 1.0
#    4. Land Square Feet  memiliki median 3854.481179
#    5. Gross Square Feet memiliki median 3894.415813
#    6. Sale Price dengan median 9.941290e+05
#
#
# 2. Pada tahun 2014,
#    1. Residental Units memiliki nilai median 1.0
#    2. Commercial Units memiliki median 0.0
#    3. Total Units memiliki median 1.0
#    4. Land Square Feet  memiliki median 3854.481179
#    5. Gross Square Feet memiliki median 3894.415813
#    6. Sale Price dengan median 1.280703e+06
#
#
# 3. Pada tahun 2015,
#    1. Residental Units memiliki nilai median 1.0
#    2. Commercial Units memiliki median 0.0
#    3. Total Units memiliki median 1.0
#    4. Land Square Feet  memiliki median 2300.000000
#    5. Gross Square Feet memiliki median 2059.000000
#    6. Sale Price dengan median 8.858770e+05
#
#
# 4. Pada tahun 2016,
#    1. Residental Units memiliki nilai median 1.0
#    2. Commercial Units memiliki median 0.0
#    3. Total Units memiliki median 1.0
#    4. Land Square Feet  memiliki median 3000.000000
#    5. Gross Square Feet memiliki median 2244.000000
#    6. Sale Price dengan median 7.203995e+05
#
#
# 5. Pada tahun 2017,
#    1. Residental Units memiliki nilai median 0.0
#    2. Commercial Units memiliki median 1.0
#    3. Total Units memiliki median 6.5
#    4. Land Square Feet  memiliki median 3367.500000
#    5. Gross Square Feet memiliki median 693.500000
#    6. Sale Price dengan median 4.350000e+05

# %% [markdown]
# ### Mode

# %%
#mencari mode dengan pandas
df.groupby('AREA').apply(pd.DataFrame.mode).reset_index(drop=True)
# Out:
#              AREA             NEIGHBORHOOD  \
# 0           Bronx                RIVERDALE
# 1        Brooklyn       BEDFORD STUYVESANT
# 2       Manhattan  UPPER EAST SIDE (59-79)
# 3          Queens           FLUSHING-NORTH
# 4  Staten Islands              GREAT KILLS
#
#                        BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  BLOCK  \
# 0  02 TWO FAMILY DWELLINGS                                        1   3944
# 1  02 TWO FAMILY DWELLINGS                                        1   2135
# 2  13 CONDOS - ELEVATOR APARTMENTS                                2     16
# 3  01 ONE FAMILY DWELLINGS                                        1   5066
# 4  01 ONE FAMILY DWELLINGS                                        1   2450
#
#    LOT BUILDING CLASS AT PRESENT                 ADDRESS APARTMENT NUMBER  \
# 0    1                        D4     2287 JOHNSON AVENUE
# 1    1                        R4         429 KENT AVENUE
# 2    1                        R4  169 WEST 95TH   STREET
# ...

# %% [markdown]
# #### _Keterangan Mode_
#
# Dari data yang ditampilkan, dijelaskan bahwa
#
# 1. Data yang sering muncul pada daerah **BRONX**
#     1. **NEIGHBORHOOD** adalah _**RIVERDALE**_
#     2. **BUILIDING CLASS CATEGORY** adalah _**02 TWO FAMILY DWELLINGS**_
#     3. **TAX CALSS AT PRESENT** adalah _**1**_
#     4. **BLOCK** adalah _**3944**_
#     5. **LOT** adalah _**1**_
#     6. **BUILIDING CLASS AT PRESENT** adalah _**D4**_
#     7. **ADDRES** adalah _**2287 JOHNSON AVENUE**_
#     8. **ZIP CODE** adalah _**10462**_
#     9. **RESIDENTAL UNITS** adalah _**1**_
#     11. **COMMERCIAL UNITS** adalah _**0**_
#     12. **TOTAL UNITS** adalah _**1**_
#     13. **LAND SQUARE FEET** adalah _**0.000000**_
#     14. **GROSS SQUARE FEET** adalah _**0.000000**_
#     15. **YEAR BUILT** adalah _**0**_
#     16. **TAX CLASS AT TIME OF SALE** adalah _**1**_
#     17. **BUILDING CLASS AT TIME OF SALE** adalah _**D4**_
#     18. **SALE PRICE** adalah _**0.000000e+00**_
#     19. **SALKE DATE** adalah _**2017-06-29**_
#
#
# 2. Data yang sering muncul pada daerah **BROKLYN**
#     1. **NEIGHBORHOOD** adalah _**BEDFORD STUYVESANT**_
#     2. **BUILIDING CLASS CATEGORY** adalah _**02 TWO FAMILY DWELLINGS**_
#     3. **TAX CALSS AT PRESENT** adalah _**1**_
#     4. **BLOCK** adalah _**2135**_
#     5. **LOT** adalah _**1**_
#     6. **BUILIDING CLASS AT PRESENT** adalah _**R4**_
#     7. **ADDRES** adalah _**429 KENT AVENUE**_
#     8. **ZIP CODE** adalah _**11201**_
#     9. **RESIDENTAL UNITS** adalah _**1**_
#     11. **COMMERCIAL UNITS** adalah _**0**_
#     12. **TOTAL UNITS** adalah _**1**_
#     13. **LAND SQUARE FEET** adalah _**0.000000**_
#     14. **GROSS SQUARE FEET** adalah _**0.000000**_
#     15. **YEAR BUILT** adalah _**0**_
#     16. **TAX CLASS AT TIME OF SALE** adalah _**1**_
#     17. **BUILDING CLASS AT TIME OF SALE** adalah _**R4**_
#     18. **SALE PRICE** adalah _**0.000000e+00**_
#     19. **SALKE DATE** adalah _**2016-10-06**_
#
#
# 3. Data yang sering muncul pada daerah **MANHATTAN**
#     1. **NEIGHBORHOOD** adalah _**UPPER EAST SIDE (59-79)**_
#     2. **BUILIDING CLASS CATEGORY** adalah _**13 CONDOS - ELEVATOR APARTMENTS**_
#     3. **TAX CALSS AT PRESENT** adalah _**2**_
#     4. **BLOCK** adalah _**16**_
#     5. **LOT** adalah _**1**_
#     6. **BUILIDING CLASS AT PRESENT** adalah _**R4**_
#     7. **ADDRES** adalah _**169 WEST 95TH STREET**_
#     8. **ZIP CODE** adalah _**10011**_
#     9. **RESIDENTAL UNITS** adalah _**0**_
#     11. **COMMERCIAL UNITS** adalah _**0**_
#     12. **TOTAL UNITS** adalah _**1**_
#     13. **LAND SQUARE FEET** adalah _**3854.481179**_
#     14. **GROSS SQUARE FEET** adalah _**3894.415813**_
#     15. **YEAR BUILT** adalah _**0**_
#     16. **TAX CLASS AT TIME OF SALE** adalah _**2**_
#     17. **BUILDING CLASS AT TIME OF SALE** adalah _**R4**_
#     18. **SALE PRICE** adalah _**1.280703e+06**_
#     19. **SALKE DATE** adalah _**2017-08-07**_
#
#
# 4. Data yang sering muncul pada daerah **QUEENS**
#     1. **NEIGHBORHOOD** adalah _**FLUSHING-NORTH**_
#     2. **BUILIDING CLASS CATEGORY** adalah _**01 ONE FAMILY DWELLINGS**_
#     3. **TAX CALSS AT PRESENT** adalah _**1**_
#     4. **BLOCK** adalah _**5066**_
#     5. **LOT** adalah _**1**_
#     6. **BUILIDING CLASS AT PRESENT** adalah _**A1**_
#     7. **ADDRES** adalah _**131-05 40TH ROAD**_
#     8. **ZIP CODE** adalah _**11354**_
#     9. **RESIDENTAL UNITS** adalah _**1**_
#     11. **COMMERCIAL UNITS** adalah _**0**_
#     12. **TOTAL UNITS** adalah _**1**_
#     13. **LAND SQUARE FEET** adalah _**3854.481179**_
#     14. **GROSS SQUARE FEET** adalah _**3894.415813**_
#     15. **YEAR BUILT** adalah _**1920**_
#     16. **TAX CLASS AT TIME OF SALE** adalah _**1**_
#     17. **BUILDING CLASS AT TIME OF SALE** adalah _**A1**_
#     18. **SALE PRICE** adalah _**1.280703e+06**_
#     19. **SALKE DATE** adalah _**2016-11-10**_
#
#
# 5. Data yang sering muncul pada daerah **STATEND ISLIND**
#     1. **NEIGHBORHOOD** adalah _**GREAT KILLS**_
#     2. **BUILIDING CLASS CATEGORY** adalah _**01 ONE FAMILY DWELLINGS**_
#     3. **TAX CALSS AT PRESENT** adalah _**1**_
#     4. **BLOCK** adalah _**2450**_
#     5. **LOT** adalah _**1**_
#     6. **BUILIDING CLASS AT PRESENT** adalah _**A5**_
#     7. **ADDRES** adalah _**1235 FOREST HILL ROAD**_
#     8. **ZIP CODE** adalah _**10314**_
#     9. **RESIDENTAL UNITS** adalah _**1**_
#     11. **COMMERCIAL UNITS** adalah _**0**_
#     12. **TOTAL UNITS** adalah _**1**_
#     13. **LAND SQUARE FEET** adalah _**3854.481179**_
#     14. **GROSS SQUARE FEET** adalah _**3894.415813**_
#     15. **YEAR BUILT** adalah _**1970**_
#     16. **TAX CLASS AT TIME OF SALE** adalah _**1**_
#     17. **BUILDING CLASS AT TIME OF SALE** adalah _**A5**_
#     18. **SALE PRICE** adalah _**1.280703e+06**_
#     19. **SALKE DATE** adalah _**2017-03-01**_

# %% [markdown]
# # Measure of Spread

# %% [markdown]
# 1. Range : Selisih antara nilai terbesar dan terkecil dalam suatu data.
# 2. Variance : Ukuran penyebaran yang mengukur seberapa jauh data tersebar dari nilai rata-rata. Varians merupakan rata-rata dari kuadrat selisih antara setiap data dengan nilai rata-rata.
# 3. Standard Deviation : Akar kuadrat dari varians.

# %% [markdown]
# ## Rumusan Masalah

# %% [markdown]
# 1. Berapakah range units, luas, dan harga pada 5 tahun terahkir?
# 2. Berapakah Variance dari units, luas, dan harga pada 5 tahun terahkir?
# 3. Berapakah Standart Deviasi dari  dari units, luas, dan harga pada 5 tahun terahkir?

# %% [markdown]
# ### Range

# %%
#mencari range dengan padnas
range_data = df.groupby(["YEAR BUILT"])[['RESIDENTIAL UNITS','COMMERCIAL UNITS','TOTAL UNITS','LAND SQUARE FEET','GROSS SQUARE FEET','SALE PRICE']].agg(np.ptp)
range_data.tail(5)
# Out:
#             RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# YEAR BUILT
# 2013                      233                25          234
# 2014                      233               318          317
# 2015                      233               254          253
# 2016                      550                 4          551
# 2017                       10               422          421
#
#             LAND SQUARE FEET  GROSS SQUARE FEET    SALE PRICE
# YEAR BUILT
# 2013                499600.0      348263.000000  6.773410e+07
# 2014                 50000.0      533600.000000  2.033450e+08
# 2015                 57936.0      167943.000000  1.740000e+08
# 2016                110303.0      143700.000000  2.545625e+07
# 2017                 12344.0        3894.415813  1.280703e+06

# %% [markdown]
# #### _Keterangan NIlai Range_
# Data diatas adalah menampilkan range untuk kolom Residental Units, Comercial Units, Total Units, Lands Feet, Gross Square Feet , dan Sale Price pada 5 tahun terahkir

# %% [markdown]
# ### Variance

# %%
#mencari variance dengan pandas
variance_data = df.groupby(["YEAR BUILT"])[['RESIDENTIAL UNITS','COMMERCIAL UNITS','TOTAL UNITS','LAND SQUARE FEET','GROSS SQUARE FEET','SALE PRICE']].var()
variance_data.tail(5)
# Out:
#             RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  \
# YEAR BUILT
# 2013               225.014730          0.895026    227.840736
# 2014               204.445214        116.380010    320.302738
# 2015               126.595829        131.940425    256.241979
# 2016               888.771519          0.089605    891.540613
# 2017                16.000000      47320.566667  46662.966667
#
#             LAND SQUARE FEET  GROSS SQUARE FEET    SALE PRICE
# YEAR BUILT
# 2013            3.407325e+08       3.508320e+08  3.254246e+13
# 2014            6.425591e+06       5.207500e+08  5.147128e+13
# 2015            8.997277e+06       1.026626e+08  2.339504e+13
# 2016            4.465299e+07       3.368749e+07  1.782244e+12
# 2017            3.287328e+07       3.644814e+06  4.149752e+11

# %% [markdown]
# #### _Keterangan NIlai Variance_
# Data diatas adalah menampilkan Variance untuk kolom Residental Units, Comercial Units, Total Units, Lands Feet, Gross Square Feet , dan Sale Price pada 5 tahun terahkir

# %% [markdown]
# ### Standart Deviasi

# %%
#mencari STD dengan pandas
std_data = df.groupby(["YEAR BUILT"])[['RESIDENTIAL UNITS','COMMERCIAL UNITS','TOTAL UNITS','LAND SQUARE FEET','GROSS SQUARE FEET','SALE PRICE']].std()
std_data.tail(5)
# Out:
#             RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# YEAR BUILT
# 2013                15.000491          0.946058    15.094394
# 2014                14.298434         10.787957    17.897004
# 2015                11.251481         11.486532    16.007560
# 2016                29.812271          0.299341    29.858677
# 2017                 4.000000        217.532909   216.016126
#
#             LAND SQUARE FEET  GROSS SQUARE FEET    SALE PRICE
# YEAR BUILT
# 2013            18458.941103       18730.510997  5.704600e+06
# 2014             2534.874886       22819.947917  7.174349e+06
# 2015             2999.546162       10132.254153  4.836842e+06
# 2016             6682.289595        5804.092786  1.335007e+06
# 2017             5733.522632        1909.139616  6.441857e+05

# %% [markdown]
# #### _Keterangan NIlai Standart Deviasi_
# Data diatas adalah menampilkan Variance untuk kolom Residental Units, Comercial Units, Total Units, Lands Feet, Gross Square Feet , dan Sale Price pada 5 tahun terahkir

# %% [markdown]
# # Probability Distribution

# %% [markdown]
# Sekarang kita akan melakukan  beberapa jenis probabilitas distribusi

# %% [markdown]
# Rumusan Masalah
# > melihat distribusi probabilitas berdasarkan Total Units

# %% [markdown]
# ## Uniform Distribusi

# %% [markdown]
# bentuk distribusi probabilitas di mana suatu peristiwa memiliki kemungkinan yang sama untuk terjadi dalam interval tertentu
#
# Untuk Uniform Distribution, gunakan **uniform.rvs(size= jumlah data, loc= mean, scale= standard deviasi)**

# %%
from scipy.stats import uniform  # Mengimport modul uniform dari scipy.stats
dist_uniform = uniform.rvs(size=84548, loc=2, scale=19)  # Menghasilkan distribusi seragam dengan rata-rata 2 dan skala 19 sebanyak 84548 data
sns.distplot(dist_uniform, bins=100)  # Membuat histogram dengan 100 bins menggunakan modul seaborn dan menampilkan distribusi seragam
plt.xlabel('Uniform Distribution berdasarkan total units')  # Menambahkan label sumbu x pada histogram
plt.ylabel('Frequency')  # Menambahkan label sumbu y pada histogram
plt.show()  # Menampilkan histogram
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn  # Mengimport modul seaborn
import matplotlib.pyplot as plt  # Mengimport modul pyplot dari matplotlib

from scipy.stats import uniform  # Mengimport modul uniform dari scipy.stats
dist_uni = uniform.rvs(size=84548, loc=2, scale=19)  # Menghasilkan distribusi seragam dengan rata-rata 2 dan skala 19 sebanyak 84548 data
graph = seaborn.displot(dist_uni)  # Membuat histogram menggunakan modul seaborn dan menyimpannya dalam variabel graph
plt.xlabel('Uniform Distribution berdasarkan total units')  # Menambahkan label sumbu x pada histogram
plt.ylabel('Frequency')  # Menambahkan label sumbu y pada histogram
plt.show()  # Menampilkan histogram

# %% [markdown]
# ## Normal Distribusi

# %% [markdown]
# Normal Distribution, juga dikenal sebagai Gaussian distribution, ada di mana-mana dalam Data Science. Kita akan menemukannya di banyak tempat terutama dalam topik inferensi statistik.

# %% [markdown]
# **Keterangan**<br>
#     Untuk Normal Distribution, gunakan **norm.rvs(size= jumlah data, loc= mean, scale= standard deviasi)**

# %%
from scipy.stats import norm  # mengimport modul norm dari scipy.stats
import seaborn as sns  # mengimport modul seaborn dan memberi nama sns
import matplotlib.pyplot as plt  # mengimport modul pyplot dari matplotlib dan memberi nama plt

# menghasilkan 84,548 data yang terdistribusi normal dengan rata-rata 2 dan standar deviasi 19
dist_norm = norm.rvs(size=84548, loc=2, scale=19)

# membuat histogram distribusi normal menggunakan seaborn
sns.histplot(dist_norm)

# memberi label pada sumbu x histogram
plt.xlabel('Normal Distribution berdasarkan total units')

# memberi label pada sumbu y histogram
plt.ylabel('Frequency')

# menampilkan histogram
plt.show()

# %%
dist_nor = norm.rvs(size=84548, loc=2, scale=19)   # Menghasilkan distribusi normal dengan rata-rata 2 dan skala 19 sebanyak 84548 data

graph = sns.displot(dist_nor)        # Membuat histogram menggunakan modul seaborn dan menampilkan distribusi normal
plt.xlabel('Normal Distribution berdasarkan total units')   # Menambahkan label sumbu x pada histogram
plt.ylabel('Frequency')             # Menambahkan label sumbu y pada histogram
plt.show()                          # Menampilkan histogram

# %% [markdown]
# ## Gamma Distribution

# %% [markdown]
# Gamma adalah distribusi probabilitas kontinu yang digunakan untuk menggambarkan jumlah waktu atau jarak yang diperlukan sebelum terjadinya peristiwa tertentu dalam proses stokastik. Distribusi ini sering digunakan dalam bidang keuangan, sains, dan teknik.

# %%
from scipy.stats import gamma   # Mengimport modul gamma dari scipy.stats
dist_gam = gamma.rvs(size=84548, a=5)   # Menghasilkan distribusi gamma dengan parameter a=5 dan sebanyak 84548 data
plt.xlabel('Gamma Distribution berdasarkan total units')   # Menambahkan label sumbu x pada histogram
plt.ylabel('Frequency')   # Menambahkan label sumbu y pada histogram
sns.distplot(dist_gam)   # Membuat histogram menggunakan modul seaborn dan menampilkan distribusi gamma
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Gamma Distribution berdasarkan total units', ylabel='Frequency'>

# %%
dist_gamma = gamma.rvs(size=84548,a=5)
graph = seaborn.displot(dist_gamma)
plt.xlabel('Normal Distribution berdasarkan total units')
plt.ylabel('Frequency')
# Out:
# Text(-2.700000000000003, 0.5, 'Frequency')

# %% [markdown]
# # Confident Intervlas

# %% [markdown]
# Rumusan Masalah
#
# Berapa interval dari rata rata jual pada tahun 2014?

# %%
c = df.groupby('YEAR BUILT').agg({"SALE PRICE": [np.mean, np.std, np.size]})
c.tail(5)
# Out:
#               SALE PRICE
#                     mean           std  size
# YEAR BUILT
# 2013        2.882327e+06  5.704600e+06   742
# 2014        2.204815e+06  7.174349e+06  1230
# 2015        1.453862e+06  4.836842e+06  1465
# 2016        8.763765e+05  1.335007e+06   792
# 2017        5.719010e+05  6.441857e+05     6

# %% [markdown]
# Sekarang mari kita hitung rata rata

# %%
mean_2014 = 2.204815e+06  # rata-rata harga properti dpada tahun 2014
std_2014 = 7.174349e+06 # standar deviasi harga properti pada tahun 2014
n = 1230 # jumlah properti di 2014
z = 1.96 # z-score berdasarkan tabel z
se = std_2014 / np.sqrt(n) # menghitung standart eror

# menghitung CI
lower = mean_2014 - z*se
upper = mean_2014 + z*se
print("The lower class boundary is", lower)
print("The upper class boundary is", upper)
# Out:
# The lower class boundary is 1803868.880130629
# The upper class boundary is 2605761.119869371

# %% [markdown]
# berdasar hasil diatas, rata rata harga penjualan (sale price) pada tahun 2014 berada di antara 1803868.880130629 sampai 2605761.119869371 dengan peluang atau selang kepercayaan 69,22%

# %% [markdown]
# **Kesimpulan**
#
# Berdasarkan perhitungan diatas, diperoleh hasil sebagai berikut. <br>
# Confidence interval = $\mu \pm (z-score \times se)$
# 1.  $\mu - (z_score \times se) = 1803868.880130629 $
# 2.  $\mu + (z_score \times se) = 2605761.119869371 $

# %% [markdown]
# # Hipotesis Testing

# %% [markdown]
# Rumusan Masalah :
#
# Dengan mempertimbangkan data NYC Property, apakah tahun 2017  memiliki nilai rata rata yang TOTAL UNIT lebih tinggi dari tahun 2002?
#
# H0: Rata-rata TOTAL UNIT properti di tahun 2017 > rata rata harga jual di tahun 2002
#
# H1: Rata-rata TOTAL UNIT properti di tahun 2017 < rata rata harga jual di tahun 2002

# %%
yb_17 = df[df["YEAR BUILT"] == 2017]

yb_02 = df[df["YEAR BUILT"] == 2002]

n_17 = len(yb_17)

mean_17 = yb_17["TOTAL UNITS"].mean()

std_17 = yb_17["TOTAL UNITS"].std()

print('rata-rata TOTAL UNIT pada tahun 2017 =',mean_17)
print('standar deviasi TOTAL UNIT pada tahun 2017 =',std_17)
# Out:
# rata-rata TOTAL UNIT pada tahun 2017 = 143.16666666666666
# standar deviasi TOTAL UNIT pada tahun 2017 = 216.01612594125163

# %%
n_02 = len(yb_02)

mean_02 = yb_02["TOTAL UNITS"].mean()

std_02 = yb_02["TOTAL UNITS"].std()

print('rata-rata TOTAL UNIT pada tahun 2002 =',mean_02)
print('standar deviasi TOTAL UNIT pada tahun 2002 =',std_02)
# Out:
# rata-rata TOTAL UNIT pada tahun 2002 = 1.3326810176125246
# standar deviasi TOTAL UNIT pada tahun 2002 = 0.7322329895544867

# %% [markdown]
# Berdasarkan hasil yang diperoleh, didapati bahwa:<br>
# rata-rata TOTAL UNIT pada tahun 2017 =  143.16666666666666
#
# rata-rata sale price di FLUSHING-NORTH =  1.3326810176125246
#
# Dengan demikian, diperoleh bahwa $143.16666666666666$ > $1.33268101761252469$. <br>
# Artinya, h0 ditolak.

# %%
143.16666666666666>1.3326810176125246
# Out:
# True
